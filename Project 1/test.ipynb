# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
array = np.array([[0,1,2,3,4,5,6,7]], dtype=np.uint8)

plt.imshow(array, cmap='gray')
plt.show()

# %%
array.shape
# Out:
# (1, 8)

# %%
img = cv2.imread("/Users/josephpalacios/Desktop/School/Fall 2023/ImageProcessing/Project 1/ImageSet1/O_EK000721.JPG")
plt.imshow(img, cmap='gray')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img_y = cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb)

cv2.imshow('img' ,img_y[:,:,0])
cv2.waitKey(0)
cv2.destroyAllWindows
